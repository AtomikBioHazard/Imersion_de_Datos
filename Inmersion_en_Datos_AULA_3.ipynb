# %% [markdown]
# <a href="https://colab.research.google.com/github/AtomikBioHazard/Imersion_de_Datos/blob/main/Inmersion_en_Datos_AULA_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 1**

# %%
from google.colab import drive
drive.mount('/content/dive')
# Out:
# Mounted at /content/dive

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = { 'Baños': 'Banos', 'Área': 'Area' }
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#                      Tipo                                    Descripcion  \
# 7299                 Casa                      Casa en venta en Engativa
# 4091          Apartamento                Apartamento en venta en Usaquén
# 2834          Apartamento               Apartamento en venta en Cedritos
# 8731          Apartamento                Apartamento en venta en Usaquén
# 8145                 Casa                          Casa en venta en Bosa
# 5111                 Casa                     Casa en venta en Chapinero
# 5151          Apartamento            Apartamento en venta en Bella Suiza
# 8889                 Casa                     Casa en venta en Chapinero
# 2791          Apartamento                   Apartamento en venta en Bosa
# 4844  Oficina/Consultorio  Oficina/Consultorio en venta en La Candelaria
#
#       Habitaciones  Banos  Area         Barrio  \
# 7299             3      2    72       Engativa
# 4091             3      3   160        Usaquén
# 2834             4      5   134       Cedritos
# 8731             1      2    63        Usaquén
# 8145             3      3    32           Bosa
# 5111             1      1   511      Chapinero
# 5151             2      2    63    Bella Suiza
# 8889             3      3   107      Chapinero
# 2791             3      2    57           Bosa
# 4844             1      1    24  La Candelaria
#
#                                         UPZ            Valor
# 7299                               Engativá    $ 320.000.000
# 4091                                Usaquén    $ 830.000.000
# 2834                                Usaquén    $ 880.000.000
# 8731                                Usaquén    $ 450.000.000
# 8145                           Bosa Central    $ 240.000.000
# 5111     CHAPINERO: Pardo Rubio + Chapinero  $ 3.200.000.000
# 5151  USAQUÉN: Country Club + Santa Bárbara    $ 285.000.000
# 8889     CHAPINERO: Pardo Rubio + Chapinero    $ 380.000.000
# 2791                           Bosa Central    $ 145.000.000
# 4844                          La Candelaria     $ 74.300.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 3245  Apartamento             Apartamento en venta en Kennedy             3
# 1008  Apartamento            Apartamento en venta en Santa Fe             1
# 3679  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 8171         Casa                       Casa en venta en Suba             3
# 8183  Apartamento     Apartamento en venta en Chico Reservado             3
# ...           ...                                         ...           ...
# 685   Apartamento             Apartamento en venta en Tintala             2
# 4865  Apartamento         Apartamento en venta en Teusaquillo             3
# 6558  Apartamento           Apartamento en venta en Chapinero             3
# 6763  Apartamento     Apartamento en venta en Chico Reservado             2
# 7553  Apartamento           Apartamento en venta en Chapinero             3
#
#       Banos  Area              Barrio                                     UPZ  \
# 3245      1    49             Kennedy                         Kennedy Central
# 1008      2    53            Santa Fe  SANTA FE: Las Nieves + Sagrado Corazón
# 3679      2    80  Zona Noroccidental      CHAPINERO: Pardo Rubio + Chapinero
# 8171      2    66                Suba                                    Suba
# 8183      3   260     Chico Reservado      CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...                 ...                                     ...
# 685       1    45             Tintala                                 Tintala
# 4865      2    67         Teusaquillo                             Teusaquillo
# 6558      5   230           Chapinero      CHAPINERO: Pardo Rubio + Chapinero
# 6763      3   130     Chico Reservado      CHAPINERO: Chicó Lago + El Refugio
# 7553      2    79           Chapinero      CHAPINERO: Pardo Rubio + Chapinero
#
#                 Valor
# 3245    $ 149.000.000
# 1008    $ 438.000.000
# 3679    $ 385.000.000
# 8171    $ 196.000.000
# 8183    $ 820.000.000
# ...               ...
# 685     $ 183.000.000
# 4865    $ 395.000.000
# 6558  $ 1.600.000.000
# 6763    $ 920.000.000
# 7553    $ 420.000.000
#
# [100 rows x 8 columns]

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == 'Chico Reservado')
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# # Desafio 1:
# Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.

# %%
inmuebles_top_ten = inmuebles.groupby('Barrio')['Area'].mean().nlargest(10)
inmuebles_top_ten
# Out:
# Barrio
# Modelia                  4316.750000
# Libertador                642.000000
# Bosa Piamonte             400.000000
# La Soledad                378.625000
# Restrepo                  336.500000
# Santa Librada             328.000000
# Las Ferias                320.000000
# Santa Ana                 309.375000
# Veraguas                  302.666667
# Bellavista Occidental     286.200000
# Name: Area, dtype: float64

# %%
inmuebles_top_ten.plot.bar()
# Out:
# <Axes: xlabel='Barrio'>

# %% [markdown]
# # Desafio 2:
#
# Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000

# %% [markdown]
# #**Aula 2**

# %%
inmuebles.sample(5)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 8144  Apartamento  Apartamento en venta en Ciudad Bolívar             3
# 1470  Apartamento         Apartamento en venta en Usaquén             3
# 384   Apartamento         Apartamento en venta en Tintala             4
# 676   Apartamento      Apartamento en venta en Cantagallo             2
# 3387  Apartamento            Apartamento en venta en Bosa             2
#
#       Banos  Area          Barrio  \
# 8144      2    56  Ciudad Bolívar
# 1470      2    56         Usaquén
# 384       2    88         Tintala
# 676       2    60      Cantagallo
# 3387      1    45            Bosa
#
#                                                     UPZ          Valor
# 8144  CIUDAD BOLÍVAR: Monteblanco + El Tesoro + El M...  $ 230.000.000
# 1470                                            Usaquén  $ 280.000.000
# 384                                             Tintala  $ 390.000.000
# 676                                            Britalia  $ 387.000.000
# 3387                                       Bosa Central  $ 115.500.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0] + inmuebles.Valor[1]
# Out:
# '$ 360.000.000$ 670.000.000'

# %%
inmuebles.Valor[0]+inmuebles.Valor[1]+inmuebles.Valor[:5]
# Out:
# 0      $ 360.000.000$ 670.000.000$ 360.000.000
# 1      $ 360.000.000$ 670.000.000$ 670.000.000
# 2    $ 360.000.000$ 670.000.000$ 1.120.000.000
# 3      $ 360.000.000$ 670.000.000$ 890.000.000
# 4      $ 360.000.000$ 670.000.000$ 970.000.000
# Name: Valor, dtype: object

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
valor = inmuebles.Valor.str.split(expand = True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 7536  Apartamento        Apartamento en venta en Chapinero             3
# 6698  Apartamento         Apartamento en venta en Cedritos             3
# 884   Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 7536      3   211        Chapinero  CHAPINERO: Pardo Rubio + Chapinero
# 6698      3   122         Cedritos                             Usaquén
# 884       3   249  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor Moneda         Precio
# 7536  $ 1.300.000.000      $  1.300.000.000
# 6698    $ 516.000.000      $    516.000.000
# 884   $ 2.200.000.000      $  2.200.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio'].sum()
# Out:
# '360.000.000670.000.0001.120.000.000890.000.000970.000.000510.000.000500.000.0002.350.000.000850.000.000642.000.000652.000.000168.000.000205.000.000300.000.000680.000.0002.519.000.000420.000.000620.000.000239.000.0001.600.000.000420.000.000625.000.0002.799.000.0001.450.000.0002.000.000.000670.000.0001.800.000.000469.000.000580.000.000445.000.000261.500.000278.000.000258.000.000520.000.000200.000.000129.000.000350.000.000290.500.000750.000.000495.000.000285.000.000900.000.0001.800.000.000990.000.000418.000.000349.000.000565.000.000370.000.000259.000.000310.000.000354.000.000372.000.000500.000.000420.000.0001.050.000.000185.000.000349.000.000515.000.000287.000.000265.000.000500.000.000261.500.000300.000.000278.000.000258.000.000520.000.000350.000.000290.500.000129.000.000200.000.000750.000.000418.000.000495.000.000349.000.000310.000.000565.000.000370.000.000259.000.000354.000.000285.000.000420.000.000372.000.000500.000.000185.000.0001.050.000.000349.000.0001.800.000.000900.000.000990.000.000225.000.000148.000.000331.500.000300.000.0001.030.000.000195.000.000200.000.000168.000.000323.000.000275.000.000510.000.000176.000.000680.000.000680.000.000217.000.0001.050.000.000375.000.000458.000.0002.000.000.000425.000.000318.000.000660.000.000730.000.000140.000.000343.000.000385.000.0001.300.000.0001.195.000.000519.000.000350.000.000202.000.000429.000.000640.000.000435.000.000610.000.000650.000.000421.000.0001.300.000.000155.000.000530.000.000330.000.000225.000.000143.000.000245.500.000433.000.000315.000.000450.000.000350.000.000205.000.0001.200.000.000169.000.000375.000.000460.000.000308.000.0001.100.000.000400.000.000860.000.0001.650.000.000565.000.000238.000.000503.000.000330.000.000400.000.0001.650.000.000580.000.000503.000.000635.000.000499.000.000371.000.000179.000.000348.200.000238.000.000173.000.000257.000.0001.100.000.000298.500.000680.000.000680.000.000217.000.0001.050.000.000375.000.000660.000.000318.000.000458.000.000425.000.0002.000.000.000343.000.000730.000.000140.000.0001.300.000.000385.000.000369.000.000366.000.000378.000.000355.000.000700.000.000990.000.000600.000.000516.000.000350.000.000475.000.000749.000.0001.195.000.000498.000.000269.000.000153.000.000335.000.000399.000.000373.000.000415.000.0001.550.000.000460.000.000225.000.000200.000.000234.000.000199.000.000450.000.0001.400.000.000202.000.000350.000.000519.000.000310.000.000355.000.000545.000.000720.000.000650.000.000343.000.000127.000.000370.000.000162.000.0001.560.000.000136.000.000265.000.000131.000.000416.000.000161.000.000900.000.000389.000.000190.000.000139.000.000319.000.000327.000.000474.500.000308.000.000720.000.000310.000.000177.500.0001.200.000.000380.000.000210.000.0001.290.000.000320.000.000445.000.000340.000.000510.000.000465.000.000220.000.000337.000.000260.000.000445.000.000290.000.000342.514.000625.000.000490.000.000350.000.000444.150.000360.000.000370.000.000150.000.000232.500.000271.000.000450.000.000163.500.000390.000.000300.000.000406.000.000465.000.000390.000.000175.000.000445.000.000422.000.000690.000.000445.000.000357.000.000465.000.000164.000.000300.000.000406.000.0001.700.000.000570.000.000460.000.000960.000.000510.000.000520.000.000142.000.000750.000.000160.000.000445.000.000570.000.000319.981.523510.000.000380.000.000134.000.000120.000.000460.000.000560.000.000351.000.0001.390.000.000422.000.000260.000.000980.000.000116.100.000980.000.000237.000.000320.000.000530.000.000503.000.000117.000.0001.300.000.000477.000.000450.000.000515.000.000730.000.000600.000.000480.000.000560.000.000308.000.000365.000.0001.200.000.000371.000.000850.000.000428.000.000421.000.000650.000.000295.000.000144.000.000280.000.000162.000.000620.000.0001.200.000.000360.000.000350.000.000650.000.000560.000.000295.000.000413.500.0001.200.000.000370.000.000600.000.000390.000.000447.500.000132.000.000180.000.000285.000.000620.000.000400.000.0001.380.000.000335.238.800820.000.000545.000.000217.000.000495.000.000330.000.000570.000.000280.000.0002.000.000.000390.000.000311 ...

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.', '', regex = True)

# %%
inmuebles[['Precio', 'Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float') / 1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins = 100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
grafica = sns.histplot(data=inmuebles, x='Precio_Millon', kde = True, hue = 'Tipo')
grafica.set_title('Distribucion de valores de los inmuebles en Bogota')
plt.xlim((50, 1000))
plt.savefig('/content/dive/MyDrive/Inmersion_de_Datos/valor_inmuebles.png', format='png')
plt.show()

# %% [markdown]
# # Desafio 1
#
# Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información)

# %%
plt.figure(figsize=(10, 7))
sns.set_style('darkgrid')
inmuebles_varios = inmuebles.query('Tipo in ["Local", "Bodega", "Lote"]')
grafica_inmuebles_varios = sns.histplot(data=inmuebles_varios, x='Precio_Millon', hue='Tipo')
grafica_inmuebles_varios.set_title('Distribucion de Valores en los Inmuebles de Bogota')
grafica_inmuebles_varios.set_xlabel('Precios por Millon')
grafica_inmuebles_varios.set_ylabel('Inmuebles')
plt.xlim((50, 2500))
plt.savefig('/content/dive/MyDrive/Inmersion_de_Datos/desafio1_aula2.png', format='png')
plt.show()

# %% [markdown]
# **Conclusion**
#
# Las bodegas son las que menos hay en cantidad y su precio es el más bajo mientras que los locales son los que más abundan de entre los 3 tipos de propiedades elegidos y tienen el mayor costo, finalmente los lotes si bien no hay tantas propiedades, si existen en diferentes rangos de precios.

# %% [markdown]
# # Desafio 2
#
# Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.

# %%
inmuebles['metro_cuadrado'] = inmuebles['Precio_Millon'] / inmuebles['Area']
metro_cuadrado_barrio = inmuebles.groupby('Barrio')['metro_cuadrado'].mean().sort_values(ascending=False)
inmuebles.sample(10)
# Out:
#              Tipo                                Descripcion  Habitaciones  \
# 4818  Apartamento               Apartamento en venta en Suba             2
# 7637  Apartamento           Apartamento en venta en Fontibón             3
# 2944  Apartamento               Apartamento en venta en Bosa             3
# 1447         Casa        Casa en venta en Zona Noroccidental             4
# 6281         Casa                   Casa en venta en Usaquén             3
# 2605         Casa        Casa en venta en Zona Noroccidental             4
# 2131  Apartamento            Apartamento en venta en Usaquén             3
# 7747  Apartamento      Apartamento en venta en Pinar De Suba             3
# 4379  Apartamento            Apartamento en venta en Usaquén             3
# 1434  Apartamento  Apartamento en venta en Chapinero Central             3
#
#       Banos  Area              Barrio                                 UPZ  \
# 4818      2    68                Suba                                Suba
# 7637      1    50            Fontibón                            Fontibón
# 2944      1    47                Bosa                        Bosa Central
# 1447      4   406  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 6281      4   189             Usaquén                             Usaquén
# 2605      6   583  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 2131      2    95             Usaquén                             Usaquén
# 7747      2    78       Pinar De Suba                                Suba
# 4379      3   151             Usaquén                             Usaquén
# 1434      2    81   Chapinero Central           Localidad Chapinero resto
#
#                 Valor Moneda      Precio  Precio_Millon  metro_cuadrado
# 4818    $ 275.000.000      $   275000000         275.00            4.04
# 7637    $ 150.000.000      $   150000000         150.00            3.00
# 2944    $ 131.000.000      $   131000000         131.00            2.79
# 1447  $ 2.500.000.000      $  2500000000        2500.00            6.16
# 6281    $ 700.000.000      $   700000000         700.00            3.70
# 2605  $ 2.650.000.000      $  2650000000        2650.00            4.55
# 2131    $ 450.000.000      $   450000000         450.00            4.74
# 7747    $ 340.000.000      $   340000000         340.00            4.36
# 4379    $ 670.000.000      $   670000000         670.00            4.44
# 1434    $ 450.000.000      $   450000000         450.00            5.56

# %%
plt.figure(figsize=(15, 10))
grafica_barrio = sns.barplot(data=inmuebles, x='metro_cuadrado', y='Barrio', palette='dark')
grafica_barrio.set_title('Precio del Metro Cuadrado por Barrio')
grafica_barrio.set_xlabel('Metro Cuadrado')
grafica_barrio.set_ylabel('Barrio')
plt.xlim((1, 9))
plt.ylim((0, 20))
plt.savefig('/content/dive/MyDrive/Inmersion_de_Datos/desafio2_aula2.png', format='png')
plt.show()

# %% [markdown]
# #**Aula 3**

# %%
inmuebles['Valor_m2_Millon'] = inmuebles['Precio_Millon'] / inmuebles['Area']
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  metro_cuadrado  \
# 0    $ 360.000.000      $   360000000         360.00            5.14
# 1    $ 670.000.000      $   670000000         670.00            3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00            7.78
#
#    Valor_m2_Millon
# 0             5.14
# 1             3.94
# 2             7.78

# %%
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_Millon  metro_cuadrado  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00            5.98
# Alhambra                    3.00   2.94 190.41         752.35            4.33
# Andes Norte                 3.00   2.86 124.86         709.57            6.05
# Antonio Nariño              4.31   2.50 163.06         459.22            3.53
# Barrancas                   2.87   2.13  70.20         314.13            4.42
# ...                          ...    ...    ...            ...             ...
# Villa Maria                 4.69   3.69 207.15         402.85            2.04
# Villas De Granada           3.45   2.32  86.59         282.30            3.17
# Villemar                    2.94   2.06  76.89         303.83            3.99
# Zona Franca                 2.00   1.00  54.00         160.00            2.96
# Zona Noroccidental          3.17   2.51 135.79         620.81            4.62
#
#                     Valor_m2_Millon
# Barrio
# Alameda                        5.98
# Alhambra                       4.33
# Andes Norte                    6.05
# Antonio Nariño                 3.53
# Barrancas                      4.42
# ...                             ...
# Villa Maria                    2.04
# Villas De Granada              3.17
# Villemar                       3.99
# Zona Franca                    2.96
# Zona Noroccidental             4.62
#
# [149 rows x 6 columns]

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     metro_cuadrado  Valor_m2_Millon
# Barrio
# Alameda                       5.98             5.98
# Alhambra                     73.56            73.56
# Andes Norte                  42.35            42.35
# Antonio Nariño              169.47           169.47
# Barrancas                    66.24            66.24
# ...                            ...              ...
# Villa Maria                  26.58            26.58
# Villas De Granada            69.71            69.71
# Villemar                     71.81            71.81
# Zona Franca                   2.96             2.96
# Zona Noroccidental         4049.16          4049.16
#
# [149 rows x 6 columns]

# %%
datos_barrio['Valor_m2_Barrio'] = datos_barrio['Precio_Millon'] / datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     metro_cuadrado  Valor_m2_Millon  Valor_m2_Barrio
# Barrio
# Alameda                       5.98             5.98             5.98
# Alhambra                     73.56            73.56             3.95
# Andes Norte                  42.35            42.35             5.68
# Antonio Nariño              169.47           169.47             2.82
# Barrancas                    66.24            66.24             4.47
# ...                            ...              ...              ...
# Villa Maria                  26.58            26.58             1.94
# Villas De Granada            69.71            69.71             3.26
# Villemar                     71.81            71.81             3.95
# Zona Franca                   2.96             2.96             2.96
# Zona Noroccidental         4049.16          4049.16             4.57
#
# [149 rows x 7 columns]

# %%
m2_barrio = dict(datos_barrio['Valor_m2_Barrio'])

# %%
inmuebles['Valor_m2_Barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_Barrio'] = inmuebles['Valor_m2_Barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  metro_cuadrado  \
# 0    $ 360.000.000      $   360000000         360.00            4.57
# 1    $ 670.000.000      $   670000000         670.00            3.40
# 2  $ 1.120.000.000      $  1120000000        1120.00            8.10
# 3    $ 890.000.000      $   890000000         890.00            5.66
# 4    $ 970.000.000      $   970000000         970.00            6.29
#
#    Valor_m2_Millon  Valor_m2_Barrio
# 0             5.14             4.57
# 1             3.94             3.40
# 2             7.78             8.10
# 3             5.78             5.66
# 4             7.58             6.29

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      metro_cuadrado  Valor_m2_Millon  Valor_m2_Barrio
# 0              5.98             5.98             5.98
# 1             73.56            73.56             3.95
# 2             42.35            42.35             5.68
# 3            169.47           169.47             2.82
# 4             66.24            66.24             4.47
# ..              ...              ...              ...
# 144           26.58            26.58             1.94
# 145           69.71            69.71             3.26
# 146           71.81            71.81             3.95
# 147            2.96             2.96             2.96
# 148         4049.16          4049.16             4.57
#
# [149 rows x 8 columns]

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      metro_cuadrado  Valor_m2_Millon  Valor_m2_Barrio
# 5           2070.61          2070.61             2.96
# 10          1654.36          1654.36             2.68
# 22          2853.23          2853.23             5.03
# 24          2466.03          2466.03             4.58
# 50          1795.71          1795.71             2.89
# 63          2127.66          2127.66             3.38
# 125         2701.88          2701.88             5.85
# 132         2000.72          2000.72             4.32
# 138         6334.04          6334.04             5.66
# 148         4049.16          4049.16             4.57

# %%
plt.figure(figsize=(10, 8))
ax = sns.barplot(x='Barrio', y='Valor_m2_Barrio', data=datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(x='Barrio', y='Valor_m2_Millon', data=inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(x='Barrio', y='Valor_m2_Millon', data=inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(x='Barrio', y='Area', data=inmuebles.query('Barrio in @top_barrios & Area < 500'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(x='Barrio', y='Precio_Millon', data=inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# Encuesta Multiproposito de Bogotá para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %%
datos_raw = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/big_data/Identificación (Capítulo A).csv', sep=';', encoding='latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# 1                            Santa Isabel  17,8555889419101
# 2  SANTA FE: Las Nieves + Sagrado Corazón  10,0286103658331
# 3   USAQUÉN: Country Club + Santa Bárbara  28,6502122142802
# 4   USAQUÉN: Country Club + Santa Bárbara  24,4684068319009

# %%
datos_raw.shape
# Out:
# (106467, 11)

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001]
datos_raw.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/big_data/Datos de la vivenda y su entorno (Capítulo B).csv',sep=';',encoding='latin-1')
datos_c = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/big_data/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
datos_e = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/big_data/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
datos_h = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/big_data/Educaci¢n (Capitulo H).csv',sep=';',encoding='latin-1')
datos_l = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/big_data/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv',sep=';',encoding='latin-1')
datos_k = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/big_data/Fuerza de trabajo (Capítulo K).csv',sep=';',encoding='latin-1')
# Out:
# <ipython-input-86-7374c3b3c0ff>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/big_data/Condiciones habitacionales del hogar (Capítulo C).csv',sep=';',encoding='latin-1')
# <ipython-input-86-7374c3b3c0ff>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/big_data/Composición del hogar y demografía (Capítulo E).csv',sep=';',encoding='latin-1')
# <ipython-input-86-7374c3b3c0ff>:4: DtypeWarning: Columns (26,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/big_data/Educaci¢n (Capitulo H).csv',sep=';',encoding='latin-1')
# <ipython-input-86-7374c3b3c0ff>:5: DtypeWarning: Columns (114,117,122,126,164,166,168) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_l = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/big_data/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv',sep=';',encoding='latin-1')
# <ipython-input-86-7374c3b3c0ff>:6: DtypeWarning: Columns (27,58,60,62,64,66,104,114,120,124,126,129,131,133) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_k = pd.read_csv('/content/dive/MyDrive/Inmersion_de_Datos/big_data/Fuerza de trabajo (Capítulo K).csv',sep=';',encoding='latin-1')

# %%
datos_dane = pd.merge(datos_raw, datos_b, on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-89-a8281422ec17>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# # Desafio 1
#
# Dar un vistazo a la base de datos del DANE, entender estas variables conceptualmente para entender mejor el contexto de esta base.

# %% [markdown]
# # Desafio 2
#
# Organizar tu notebook para que tu proyecto quede mejor presentado.
